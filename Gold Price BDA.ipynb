# %% [markdown]
# # Gold Price Analysis

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('gld_price_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303296
# 75%    2073.010070   132.840004    37.827501    22.882499     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %% [markdown]
# ## Correlation of All Price

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
plt.figure(figsize = (15,10))
sns.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values,annot=True,fmt='.4f',linewidths=0.45)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Analysis Wrt"GLD"

# %%
print (corr['GLD'].sort_values(), '\n')
# Out:
# USO       -0.186360
# EUR/USD   -0.024375
# SPX        0.049345
# SLV        0.866632
# GLD        1.000000
# Name: GLD, dtype: float64

# %%
sns.distplot(df['GLD'], color = 'red')
# Out:
# C:\Users\Amay\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GLD', ylabel='Density'>

# %%
print('Skewness:', df['GLD'].skew())
# Out:
# Skewness: 0.33413834726925085

# %%
print('Kurtosis:', df['GLD'].kurt())
# Out:
# Kurtosis: -0.2750805233458311

# %% [markdown]
# ## Analysis Wrt"EUR/USD"

# %%
print (corr['EUR/USD'].sort_values(), '\n')
# Out:
# SPX       -0.672017
# GLD       -0.024375
# SLV        0.321631
# USO        0.829317
# EUR/USD    1.000000
# Name: EUR/USD, dtype: float64

# %%
sns.distplot(df['EUR/USD'], color = 'blue')
# Out:
# C:\Users\Amay\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EUR/USD', ylabel='Density'>

# %%
print('Skewness:', df['EUR/USD'].skew())
# Out:
# Skewness: -0.005292277033840852

# %%
print('Kurtosis:', df['EUR/USD'].kurt())
# Out:
# Kurtosis: -0.7427510073241397

# %% [markdown]
# ## Analysis Wrt"SPX"

# %%
print (corr['SPX'].sort_values(), '\n')
# Out:
# EUR/USD   -0.672017
# USO       -0.591573
# SLV       -0.274055
# GLD        0.049345
# SPX        1.000000
# Name: SPX, dtype: float64

# %%
sns.distplot(df['SPX'], color = 'pink')
# Out:
# C:\Users\Amay\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SPX', ylabel='Density'>

# %%
print('Skewness:', df['SPX'].skew())
# Out:
# Skewness: 0.3003618142394941

# %%
print('Kurtosis:', df['EUR/USD'].kurt())
# Out:
# Kurtosis: -0.7427510073241397

# %% [markdown]
# ## Analysis of Price with Other Price

# %%
sns.jointplot(x =df['SPX'], y = df['GLD'], color = 'blue')

# %%
sns.jointplot(x =df['EUR/USD'], y = df['SPX'], color = 'purple')

# %%
sns.jointplot(x =df['SLV'], y = df['USO'], color = 'deeppink')

# %%
sns.jointplot(x =df['EUR/USD'], y = df['USO'], color = 'pink')

# %%
sns.jointplot(x =df['SLV'], y = df['SPX'], color = 'red')

# %%
sns.jointplot(x =df['SLV'], y = df['EUR/USD'], color = 'orange')

# %% [markdown]
# ## Predict using Random Forest

# %%
x_trail = df[['SPX','USO','SLV','EUR/USD']]
x = x_trail.iloc[:, :].values
y = df.iloc[:, 2].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(x_test)

# %% [markdown]
# ### Mean Absolute Error

# %%
from sklearn import metrics
print('Mean Absolute Error :'," ", metrics.mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error :   1.3006268049999998

# %% [markdown]
# ### Mean Squared Error

# %%
from sklearn import metrics
print('Mean Squared Error :'," ", metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error :   5.228816515789273

# %% [markdown]
# ### Squared Mean Absolute Error

# %%
from sklearn import metrics
print('Squared Mean Absolute Error :'," ", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Squared Mean Absolute Error :   2.2866605598097136

# %% [markdown]
# ### Accuracy Wrt"Train Data"

# %%
accuracy_train = regressor.score(x_train, y_train)
print(accuracy_train)
# Out:
# 0.9984081992784245

# %% [markdown]
# ### Accuracy Wrt"Test Data"

# %%
accuracy_test = regressor.score(x_test, y_test)
print(accuracy_test)
# Out:
# 0.9898360912117761

# %% [markdown]
# ## Visualising the Accuracy of Predicted result

# %% [markdown]
# ### Wrt"Train Data"

# %%
plt.plot(y_train, color = 'green', label = 'Acutal')
plt.plot(y_pred, color = 'pink', label = 'Predicted')
plt.grid(6)
plt.legend()
plt.show()

# %% [markdown]
# ### Wrt"Test Data"

# %%
plt.plot(y_test, color = 'blue', label = 'Acutal')
plt.plot(y_pred, color = 'red', label = 'Predicted')
plt.grid(6)
plt.legend()
plt.show()
